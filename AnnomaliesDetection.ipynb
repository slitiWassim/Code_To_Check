# %%
# %pwd
# Out:
# '/media/sliti-wassim/storage/Train Local/astnet/ASTNet'

# %%
# !python train.py \
    --cfg 'config/ped2_wresnet.yaml' \
    --test True\
    --pseudo True
# Out:
# => creating output/ped2/ped2_wresnet
# => creating log/ped2/wrn38/ped2_wresnet_2024-08-12-08-34
# INFO:root:Namespace(cfg='config/ped2_wresnet.yaml', model_file='pretrained/shanghaitech.pth', resume_train=False, optical=False, pseudo=True, output_folder=None, test=True, opts=[])
# Namespace(cfg='config/ped2_wresnet.yaml', model_file='pretrained/shanghaitech.pth', resume_train=False, optical=False, pseudo=True, output_folder=None, test=True, opts=[])
# ...
